# %%
pip install -r requirements.txt
# Out:
# Requirement already satisfied: keras in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 1)) (3.9.0)
# Requirement already satisfied: numpy in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 2)) (2.0.2)
# Requirement already satisfied: streamlit in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 3)) (1.43.2)
# Requirement already satisfied: opencv_python_headless in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 4)) (4.11.0.86)
# Requirement already satisfied: tensorflow in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 5)) (2.19.0)
# Requirement already satisfied: matplotlib in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from -r requirements.txt (line 6)) (3.9.4)
# Collecting scikit-learn (from -r requirements.txt (line 7))
#   Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl.metadata (15 kB)
# Requirement already satisfied: absl-py in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (2.1.0)
# Requirement already satisfied: rich in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (13.9.4)
# Requirement already satisfied: namex in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (0.0.8)
# Requirement already satisfied: h5py in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (3.13.0)
# Requirement already satisfied: optree in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (0.14.1)
# Requirement already satisfied: ml-dtypes in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (0.5.1)
# Requirement already satisfied: packaging in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from keras->-r requirements.txt (line 1)) (24.2)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.0.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (5.5.2)
# Requirement already satisfied: click<9,>=7.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (8.1.8)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (11.1.0)
# Requirement already satisfied: protobuf<6,>=3.20 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (19.0.1)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (6.0.0)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (3.1.44)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (0.9.1)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from streamlit->-r requirements.txt (line 3)) (6.4.2)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.6.3)
# Requirement already satisfied: flatbuffers>=24.3.25 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (25.2.10)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.6.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.2.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (3.4.0)
# Requirement already satisfied: setuptools in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (75.8.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.17.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (2.5.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.17.2)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (1.71.0)
# Requirement already satisfied: tensorboard~=2.19.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (2.19.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorflow->-r requirements.txt (line 5)) (0.31.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (1.4.7)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (3.2.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from matplotlib->-r requirements.txt (line 6)) (6.5.2)
# Collecting scipy>=1.6.0 (from scikit-learn->-r requirements.txt (line 7))
#   Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.2.0 (from scikit-learn->-r requirements.txt (line 7))
#   Downloading joblib-1.4.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting threadpoolctl>=3.1.0 (from scikit-learn->-r requirements.txt (line 7))
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Requirement already satisfied: jinja2 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (1.30.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from astunparse>=1.6.0->tensorflow->-r requirements.txt (line 5)) (0.45.1)
# Requirement already satisfied: colorama in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from click<9,>=7.0->streamlit->-r requirements.txt (line 3)) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 3)) (4.0.12)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->-r requirements.txt (line 6)) (3.21.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from pandas<3,>=1.4.0->streamlit->-r requirements.txt (line 3)) (2025.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3)) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3)) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3)) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from requests<3,>=2.27->streamlit->-r requirements.txt (line 3)) (2025.1.31)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 5)) (3.7)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 5)) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 5)) (3.1.3)
# Requirement already satisfied: markdown-it-py>=2.2.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from rich->keras->-r requirements.txt (line 1)) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from rich->keras->-r requirements.txt (line 1)) (2.19.1)
# Requirement already satisfied: smmap<6,>=3.0.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit->-r requirements.txt (line 3)) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (3.0.2)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (25.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (2024.10.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (0.36.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit->-r requirements.txt (line 3)) (0.23.1)
# Requirement already satisfied: importlib-metadata>=4.4 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from markdown>=2.6.8->tensorboard~=2.19.0->tensorflow->-r requirements.txt (line 5)) (8.6.1)
# Requirement already satisfied: mdurl~=0.1 in c:\users\lalit\.conda\envs\mini-project\lib\site-packages (from markdown-it-py>=2.2.0->rich->keras->-r requirements.txt (line 1)) (0.1.2)
# Downloading scikit_learn-1.6.1-cp39-cp39-win_amd64.whl (11.2 MB)
#    ---------------------------------------- 0.0/11.2 MB ? eta -:--:--
#    ------------- -------------------------- 3.7/11.2 MB 18.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.3/11.2 MB 14.9 MB/s eta 0:00:01
#    ------------------------------- -------- 8.9/11.2 MB 14.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.2/11.2 MB 13.2 MB/s eta 0:00:00
# Downloading joblib-1.4.2-py3-none-any.whl (301 kB)
# Downloading scipy-1.13.1-cp39-cp39-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#    -- ------------------------------------- 3.1/46.2 MB 15.4 MB/s eta 0:00:03
#    ---- ----------------------------------- 5.8/46.2 MB 13.6 MB/s eta 0:00:03
#    ------- -------------------------------- 8.4/46.2 MB 13.0 MB/s eta 0:00:03
#    --------- ------------------------------ 10.7/46.2 MB 12.7 MB/s eta 0:00:03
#    ----------- ---------------------------- 13.4/46.2 MB 12.5 MB/s eta 0:00:03
#    ------------- -------------------------- 16.0/46.2 MB 12.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.6/46.2 MB 12.5 MB/s eta 0:00:03
#    ------------------ --------------------- 21.0/46.2 MB 12.4 MB/s eta 0:00:03
#    -------------------- ------------------- 23.6/46.2 MB 12.4 MB/s eta 0:00:02
#    ---------------------- ----------------- 26.2/46.2 MB 12.4 MB/s eta 0:00:02
#    ------------------------ --------------- 28.3/46.2 MB 12.3 MB/s eta 0:00:02
#    -------------------------- ------------- 31.2/46.2 MB 12.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.6/46.2 MB 12.3 MB/s eta 0:00:02
#    ------------------------------- -------- 36.2/46.2 MB 12.4 MB/s eta 0:00:01
#    --------------------------------- ------ 38.8/46.2 MB 12.3 MB/s eta 0:00:01
#    ----------------------------------- ---- 41.2/46.2 MB 12.3 MB/s eta 0:00:01
#    -------------------------------------- - 44.0/46.2 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  46.1/46.2 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 11.9 MB/s eta 0:00:00
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.4.2 scikit-learn-1.6.1 scipy-1.13.1 threadpoolctl-3.6.0
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.image import imread
import cv2
import random
import os
from os import listdir
from PIL import Image
import tensorflow as tf
from keras.preprocessing import image
from tensorflow. keras.utils import img_to_array, array_to_img
from keras.optimizers import Adam
from keras.models import Sequential
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Activation, Flatten, Dropout, Dense
from sklearn. model_selection import train_test_split
from keras.models import model_from_json
from keras.utils import to_categorical

# %%
print(tf. __version__)
# Out:
# 2.19.0

# %% [markdown]
# ## **Dataset Culling For a Balanced Dataset**

# %%
import os
import random
import shutil

# Define your copied folders in Colab instance
folders = {
    'Corn_(maize)___Common_rust_': r'C:\Users\lalit\Downloads\Mini-Project\dataset\Corn_(maize)___Common_rust_',
    'Potato___Early_blight': r'C:\Users\lalit\Downloads\Mini-Project\dataset\Potato___Early_blight',
    'Tomato___Bacterial_spot': r'C:\Users\lalit\Downloads\Mini-Project\dataset\Tomato___Bacterial_spot'
}

# Define the number of images to sample from each folder
num_samples_per_folder = {
    'Corn_(maize)___Common_rust_': 1700,
    'Potato___Early_blight': 1700,
    'Tomato___Bacterial_spot': 1700
}

# Destination root for sampled data
sampled_root = r'C:\Users\lalit\Downloads\Mini-Project\sampled_dataset'
os.makedirs(sampled_root, exist_ok=True)

# Cull each folder
for folder_name, folder_path in folders.items():
    # Output folder for sampled images
    output_path = os.path.join(sampled_root, folder_name)
    os.makedirs(output_path, exist_ok=True)

    # Get list of all image files in the directory
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('png', 'jpg', 'jpeg'))]
    total_images = len(image_files)

    # Number of images to sample from this folder
    num_samples = num_samples_per_folder[folder_name]

    # Adjust sampling size if not enough images are available
    if num_samples > total_images:
        print(f"⚠️ Not enough images in {folder_name}. Sampling all {total_images} images instead.")
        sampled_images = image_files  # Take all available images
    else:
        # Randomly sample images
        sampled_images = random.sample(image_files, num_samples)

    # Move or copy the sampled images to the new directory
    for image_file in sampled_images:
        source = os.path.join(folder_path, image_file)
        destination = os.path.join(output_path, image_file)
        shutil.copy(source, destination)  # Copy instead of move

    print(f'✅ Successfully culled {len(sampled_images)} images from {folder_name} to {output_path}.')
# Out:
# ✅ Successfully culled 1700 images from Corn_(maize)___Common_rust_ to C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Corn_(maize)___Common_rust_.
# ✅ Successfully culled 1700 images from Potato___Early_blight to C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Potato___Early_blight.
# ✅ Successfully culled 1700 images from Tomato___Bacterial_spot to C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Tomato___Bacterial_spot.

# %%
# Define your sampled folders in your local machine
sampled_folders = {
    'Corn_(maize)___Common_rust_': r'C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Corn_(maize)___Common_rust_',
    'Potato___Early_blight': r'C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Potato___Early_blight',
    'Tomato___Bacterial_spot': r'C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Tomato___Bacterial_spot'
}

# Function to count images in a folder

def count_images(folder_path):
    image_files = [f for f in os.listdir(folder_path) if f.lower().endswith(('png', 'jpg', 'jpeg'))]
    return len(image_files)

# Check each folder
for folder_name, folder_path in sampled_folders.items():
    num_images = count_images(folder_path)
    print(f'{folder_name}: {num_images} images found.')
# Out:
# Corn_(maize)___Common_rust_: 1700 images found.
# Potato___Early_blight: 1700 images found.
# Tomato___Bacterial_spot: 1700 images found.

# %% [markdown]
# ## **Model Training**

# %%
dataset_path = r'C:\Users\lalit\Downloads\Mini-Project\sampled_dataset'

# %%
# Plotting 12 images to check dataset

plt.figure(figsize = (12, 12))
dataset_path =  r"C:\Users\lalit\Downloads\Mini-Project\sampled_dataset\Potato___Early_blight"

for i in range(1, 17):
    plt.subplot(4, 4, i)
    plt.tight_layout()
    rand_img = imread(dataset_path +'/'+ random.choice(sorted(os.listdir(dataset_path))))
    plt.imshow(rand_img)
    plt.xlabel(rand_img.shape[1], fontsize = 10) # width of image
    plt.ylabel(rand_img.shape[0], fontsize = 10) # height of image

# %%
# Converting Images to array

def convert_image_to_array(image_dir):
    try:
        image = cv2.imread(image_dir)
        if image is not None :
            image = cv2.resize(image, (256, 256))
            return img_to_array(image)
        else :
            return np.array([])
    except Exception as e:
        print(f"Error : {e}")
        return None

# %%
dataset_path = r"C:\Users\lalit\Downloads\Mini-Project\sampled_dataset"
labels = os.listdir(dataset_path)

print(labels)
# Out:
# ['Corn_(maize)___Common_rust_', 'Potato___Early_blight', 'Tomato___Bacterial_spot']

# %%
dataset_path = r"C:\Users\lalit\Downloads\Mini-Project\sampled_dataset"
root_dir = listdir(dataset_path)
image_list, label_list = [], []
all_labels = ['Corn-Common_rust', 'Potato-Early_blight', 'Tomato-Bacterial_spot']
binary_labels = [0, 1, 2]
temp = -1

# Reading and converting image to numpy array

for directory in root_dir:
  plant_image_list = listdir(f"{dataset_path}/{directory}")
  temp += 1
  for files in plant_image_list:
    image_path = f"{dataset_path}/{directory}/{files}"
    image_list.append(convert_image_to_array(image_path))
    label_list.append(binary_labels[temp])

# %%
# Visualize the number of classes count

label_counts = pd.DataFrame(label_list).value_counts()
label_counts.head()
# Out:
# 0
# 0    1700
# 1    1700
# 2    1700
# Name: count, dtype: int64

# %%
# Next we will observe the shape of the image.

image_list[0].shape
# Out:
# (256, 256, 3)

# %%
# Checking the total number of the images which is the length of the labels list.

label_list = np.array(label_list)
label_list.shape
# Out:
# (5100,)

# %%
x_train, x_test, y_train, y_test = train_test_split(image_list, label_list, test_size=0.2, random_state = 10)

# %%
# Now we will normalize the dataset of our images. As pixel values ranges from 0 to 255 so we will divide each image pixel with 255 to normalize the dataset.

x_train = np.array(x_train, dtype=np.float16) / 225.0
x_test = np.array(x_test, dtype=np.float16) / 225.0
x_train = x_train.reshape(-1, 256, 256, 3)
x_test = x_test.reshape(-1, 256, 256, 3)

# %%
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

# %%
model = Sequential()
model.add(Conv2D(32, (3, 3), padding = "same",input_shape = (256, 256, 3), activation = "relu"))
model.add(MaxPooling2D(pool_size = (3, 3)))
model.add(Conv2D(16, (3, 3), padding = "same", activation = "relu"))
model.add(MaxPooling2D(pool_size = (2, 2)))
model.add(Flatten())
model.add(Dense(8, activation = "relu"))
model.add(Dense(3, activation = "softmax"))
model.summary()
# Out:
# c:\Users\lalit\.conda\envs\mini-project\lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 256, 256, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 85, 85, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 85, 85, 16)     │         4,624 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 42, 42, 16)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 28224)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 8)              │       225,800 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 3)              │            27 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 231,347 (903.70 KB)
#  Trainable params: 231,347 (903.70 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(loss = 'categorical_crossentropy', optimizer = Adam(0.0001), metrics = ['accuracy'])

# %%
# Splitting the training data set into training and validation data sets

x_train, x_val, y_train, y_val = train_test_split(x_train, y_train, test_size = 0.2, random_state = 10)

# %%
# Training the model

epochs = 50
batch_size = 64
history = model.fit(x_train, y_train, batch_size = batch_size, epochs = epochs, validation_data = (x_val, y_val))
# Out:
# Epoch 1/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 63s 1s/step - accuracy: 0.4772 - loss: 0.8528 - val_accuracy: 0.8260 - val_loss: 0.4322
# Epoch 2/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.8800 - loss: 0.3775 - val_accuracy: 0.9706 - val_loss: 0.2727
# Epoch 3/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9622 - loss: 0.2522 - val_accuracy: 0.9877 - val_loss: 0.2079
# Epoch 4/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 899ms/step - accuracy: 0.9783 - loss: 0.2097 - val_accuracy: 0.9877 - val_loss: 0.1519
# Epoch 5/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 949ms/step - accuracy: 0.9839 - loss: 0.1556 - val_accuracy: 0.9865 - val_loss: 0.1193
# Epoch 6/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 51s 977ms/step - accuracy: 0.9856 - loss: 0.1118 - val_accuracy: 0.9890 - val_loss: 0.0721
# Epoch 7/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 947ms/step - accuracy: 0.9862 - loss: 0.0760 - val_accuracy: 0.9890 - val_loss: 0.0541
# Epoch 8/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 46s 894ms/step - accuracy: 0.9936 - loss: 0.0523 - val_accuracy: 0.9939 - val_loss: 0.0352
# Epoch 9/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 44s 860ms/step - accuracy: 0.9926 - loss: 0.0386 - val_accuracy: 0.9988 - val_loss: 0.0259
# Epoch 10/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 936ms/step - accuracy: 0.9915 - loss: 0.0334 - val_accuracy: 0.9963 - val_loss: 0.0222
# Epoch 11/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 45s 876ms/step - accuracy: 0.9938 - loss: 0.0329 - val_accuracy: 0.9902 - val_loss: 0.0303
# Epoch 12/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 910ms/step - accuracy: 0.9955 - loss: 0.0311 - val_accuracy: 1.0000 - val_loss: 0.0131
# Epoch 13/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 928ms/step - accuracy: 0.9972 - loss: 0.0212 - val_accuracy: 1.0000 - val_loss: 0.0111
# Epoch 14/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 46s 895ms/step - accuracy: 0.9988 - loss: 0.0156 - val_accuracy: 1.0000 - val_loss: 0.0100
# Epoch 15/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 43s 829ms/step - accuracy: 0.9984 - loss: 0.0172 - val_accuracy: 0.9963 - val_loss: 0.0131
# Epoch 16/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 44s 856ms/step - accuracy: 0.9990 - loss: 0.0101 - val_accuracy: 1.0000 - val_loss: 0.0083
# Epoch 17/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 45s 877ms/step - accuracy: 0.9982 - loss: 0.0147 - val_accuracy: 1.0000 - val_loss: 0.0067
# Epoch 18/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 43s 831ms/step - accuracy: 0.9976 - loss: 0.0122 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 19/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 43s 842ms/step - accuracy: 0.9982 - loss: 0.0090 - val_accuracy: 1.0000 - val_loss: 0.0062
# Epoch 20/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 89s 987ms/step - accuracy: 0.9984 - loss: 0.0104 - val_accuracy: 1.0000 - val_loss: 0.0069
# Epoch 21/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 50s 971ms/step - accuracy: 0.9996 - loss: 0.0077 - val_accuracy: 1.0000 - val_loss: 0.0057
# Epoch 22/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 51s 975ms/step - accuracy: 0.9997 - loss: 0.0059 - val_accuracy: 1.0000 - val_loss: 0.0048
# Epoch 23/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.9986 - loss: 0.0117 - val_accuracy: 1.0000 - val_loss: 0.0055
# Epoch 24/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 907ms/step - accuracy: 0.9990 - loss: 0.0098 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 25/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 44s 868ms/step - accuracy: 0.9993 - loss: 0.0053 - val_accuracy: 1.0000 - val_loss: 0.0035
# Epoch 26/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 46s 886ms/step - accuracy: 0.9996 - loss: 0.0047 - val_accuracy: 1.0000 - val_loss: 0.0042
# Epoch 27/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 955ms/step - accuracy: 0.9999 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0039
# Epoch 28/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 51s 980ms/step - accuracy: 0.9999 - loss: 0.0036 - val_accuracy: 1.0000 - val_loss: 0.0036
# Epoch 29/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 51s 993ms/step - accuracy: 0.9999 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0038
# Epoch 30/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 952ms/step - accuracy: 0.9992 - loss: 0.0048 - val_accuracy: 1.0000 - val_loss: 0.0033
# Epoch 31/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 70s 1s/step - accuracy: 0.9997 - loss: 0.0039 - val_accuracy: 1.0000 - val_loss: 0.0027
# Epoch 32/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.9999 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0029
# Epoch 33/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 58s 1s/step - accuracy: 0.9998 - loss: 0.0029 - val_accuracy: 1.0000 - val_loss: 0.0026
# Epoch 34/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 68s 1s/step - accuracy: 0.9995 - loss: 0.0034 - val_accuracy: 1.0000 - val_loss: 0.0022
# Epoch 35/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 0.9998 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0031
# Epoch 36/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 916ms/step - accuracy: 1.0000 - loss: 0.0024 - val_accuracy: 1.0000 - val_loss: 0.0025
# Epoch 37/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 905ms/step - accuracy: 1.0000 - loss: 0.0021 - val_accuracy: 1.0000 - val_loss: 0.0020
# Epoch 38/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 81s 898ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 39/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 47s 913ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0018
# Epoch 40/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 44s 843ms/step - accuracy: 1.0000 - loss: 0.0016 - val_accuracy: 1.0000 - val_loss: 0.0017
# Epoch 41/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 930ms/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0019
# Epoch 42/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 1.0000 - loss: 0.0014 - val_accuracy: 1.0000 - val_loss: 0.0021
# Epoch 43/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 65s 1s/step - accuracy: 1.0000 - loss: 0.0018 - val_accuracy: 1.0000 - val_loss: 0.0013
# Epoch 44/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 51s 1s/step - accuracy: 1.0000 - loss: 9.7192e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 45/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 56s 1s/step - accuracy: 1.0000 - loss: 9.3939e-04 - val_accuracy: 1.0000 - val_loss: 0.0012
# Epoch 46/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 1.0000 - loss: 0.0013 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 47/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 942ms/step - accuracy: 1.0000 - loss: 8.7215e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 48/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 48s 938ms/step - accuracy: 1.0000 - loss: 7.6501e-04 - val_accuracy: 1.0000 - val_loss: 0.0011
# Epoch 49/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 49s 944ms/step - accuracy: 1.0000 - loss: 6.6502e-04 - val_accuracy: 1.0000 - val_loss: 9.4633e-04
# Epoch 50/50
# 51/51 ━━━━━━━━━━━━━━━━━━━━ 54s 1s/step - accuracy: 1.0000 - loss: 7.8135e-04 - val_accuracy: 1.0000 - val_loss: 8.7127e-04

# %%
model.save(r"C:\Users\lalit\Downloads\Mini-Project\plant_disease_model.h5")
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.

# %%
# Plot the training history

plt.figure(figsize = (12, 5))
plt.plot(history.history['accuracy'], color = 'r')
plt.plot(history.history['val_accuracy'], color = 'b')
plt.title('Model Accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epochs')
plt.legend(['train', 'val'])

plt.show()

# %%
print("Calculating model accuracy")

scores = model.evaluate(x_test, y_test)
print(f"Test Accuracy: {scores[1] * 100}")
# Out:
# Calculating model accuracy
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 109ms/step - accuracy: 0.9976 - loss: 0.0074
# Test Accuracy: 99.8039186000824

# %%
y_pred = model.predict(x_test)
# Out:
# 32/32 ━━━━━━━━━━━━━━━━━━━━ 4s 119ms/step

# %%
# Plotting image to compare

img = array_to_img(x_test[11])
img
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
# Finding max value from predition list and comaparing original value vs predicted

print("Originally : ", all_labels[np.argmax(y_test[11])])
print("Predicted : ", all_labels[np.argmax(y_pred[4])])
print(y_pred[2])
# Out:
# Originally :  Potato-Early_blight
# Predicted :  Tomato-Bacterial_spot
# [9.9999630e-01 3.7104473e-06 3.5317374e-18]

# %%
for i in range(50):
    print (all_labels[np.argmax(y_test[i])], " ", all_labels[np.argmax(y_pred [1])])
# Out:
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Potato-Early_blight   Corn-Common_rust
# Tomato-Bacterial_spot   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
# Corn-Common_rust   Corn-Common_rust
